# %% [markdown]
# # Graph SLAM Problem
#
# $\min J(x_i) = x_0^T\Omega_0 x_0 + \sum_t e_t R_t^{-1} e_t  + \sum_t \sum_i \tilde{z}^i_t  Q_t^{-1} \tilde{z}^i_t + \$

# %% [markdown]
# $ e_t \equiv x_t - g(u_t, x_{t-1})$ prediction error at time t

# %% [markdown]
# $\tilde{z}^i_t \equiv z^i_t - h(x_t, m^i_t)$ measurement error

# %% [markdown]
# $\dot{p_x} = v_x$
#
# $\dot{p_y} = v_y$
#
# $x_t = \begin{bmatrix} p_x \\ p_y \end{bmatrix}$
# $u_t = \begin{bmatrix} v_x \\ v_y \end{bmatrix}$
#
# $x_t = x_{t-1} + \Delta_t u_t $

# %% [markdown]
# $g(u_t, x_t{-1}) = x_{t-1}  + \Delta_t u_t$

# %% [markdown]
# --> 161 z_factor=np.append(z,np.expand_dims(i*np.ones[len(z),1],axis=1))Landmarks are points. And our measurement is relative position.

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
# %matplotlib qt
import numpy as np
import casadi as ca
import slam3d
import SF2D
import time
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %%
noise={
    'odom_std': 0.1,
    'bearing_std': 0,
    'range_std': 0.05,
    'odom_bx_bias': 0,
    'odom_by_bias': 0,
    'odom_bz_bias': 0
}

plt.figure(figsize=(10, 5))

t0 = time.time()

sim = slam3d.simulate(noise=noise, plot=True, symf=False, tf=5);
#sf: true-symforce, false-casadi

tf =  time.time() - t0
print('runtime [s]: ', tf)

# print(sim['hist']['lh'])

plt.figure()
plt.plot(sim['hist']['t'], sim['hist']['J'][:])
plt.grid()
# Out:
# runtime [s]:  0.19912123680114746

# %%
x=sim['hist']['xh']
lm=sim['hist']['lh'][-1]
odom=sim['hist']['odom'][:,0:2]
z = sim['hist']['z']
z = np.append(z,np.expand_dims(sim['hist']['assoc'],1),axis=1)
result = SF2D.optimize(x,lm,odom,z)
print(result.optimized_values['poses'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 x=sim['hist']['xh']
#       2 lm=sim['hist']['lh'][-1]
#       3 odom=sim['hist']['odom'][:,0:2]
#
# NameError: name 'sim' is not defined

# %%
print(sim['hist']['odom'])

# %%
x=sim['hist']['xh']
lm=sim['hist']['lh'][-1]
odom=sim['hist']['odom'][:,0:2]
z = sim['hist']['z']
z = np.append(z,np.expand_dims(sim['hist']['assoc'],1),axis=1)
result = SF2D.optimize(x,lm,odom,z)
print(result.optimized_values['poses'][0])
# Out:
# [2023-02-03 12:19:54.165] [info] LM<sym::Optimize> [iter    0] lambda: 1.000e+00, error prev/linear/new: 7.653/0.036/0.608, rel reduction: 0.92061
# [2023-02-03 12:19:54.167] [info] LM<sym::Optimize> [iter    1] lambda: 2.500e-01, error prev/linear/new: 0.608/0.021/0.075, rel reduction: 0.87725
# [2023-02-03 12:19:54.170] [info] LM<sym::Optimize> [iter    2] lambda: 6.250e-02, error prev/linear/new: 0.075/0.020/0.203, rel reduction: -1.72510
# [2023-02-03 12:19:54.172] [info] LM<sym::Optimize> [iter    3] lambda: 2.500e-01, error prev/linear/new: 0.075/0.029/0.043, rel reduction: 0.42936
# [2023-02-03 12:19:54.174] [info] LM<sym::Optimize> [iter    4] lambda: 6.250e-02, error prev/linear/new: 0.043/0.025/0.036, rel reduction: 0.15498
# [2023-02-03 12:19:54.177] [info] LM<sym::Optimize> [iter    5] lambda: 1.562e-02, error prev/linear/new: 0.036/0.016/0.148, rel reduction: -3.11826
# [2023-02-03 12:19:54.179] [info] LM<sym::Optimize> [iter    6] lambda: 6.250e-02, error prev/linear/new: 0.036/0.018/0.086, rel reduction: -1.38069
# [2023-02-03 12:19:54.182] [info] LM<sym::Optimize> [iter    7] lambda: 2.500e-01, error prev/linear/new: 0.036/0.023/0.040, rel reduction: -0.09910
# [2023-02-03 12:19:54.184] [info] LM<sym::Optimize> [iter    8] lambda: 1.000e+00, error prev/linear/new: 0.036/0.029/0.032, rel reduction: 0.09725
# [2023-02-03 12:19:54.186] [info] LM<sym::Optimize> [iter    9] lambda: 2.500e-01, error prev/linear/new: 0.032/0.032/0.032, rel reduction: 0.01391
# [2023-02-03 12:19:54.189] [info] LM<sym::Optimize> [iter   10] lambda: 6.250e-02, error prev/linear/new: 0.032/0.031/0.035, rel reduction: -0.08878
# [2023-02-03 12:19:54.192] [info] LM<sym::Optimize> [iter   11] lambda: 2.500e-01, error prev/linear/new: 0.032/0.032/0.032, rel reduction: -0.00084
# [2023-02-03 12:19:54.194] [info] LM<sym::Optimize> [iter   12] lambda: 1.000e+00, error prev/linear/new: 0.032/0.032/0.032, rel reduction: 0.00312
# [2023-02-03 12:19:54.197] [info] LM<sym::Optimize> [iter   13] lambda: 2.500e-01, error prev/linear/new: 0.032/0.032/0.032, rel reduction: 0.00361
# [2023-02-03 12:19:54.199] [info] LM<sym::Optimize> [iter   14] lambda: 6.250e-02, error prev/linear/new: 0.032/0.031/0.038, rel reduction: -0.19273
# [2023-02-03 12:19:54.202] [info] LM<sym::Optimize> [iter   15] lambda: 2.500e-01, error prev/linear/new: 0.032/0.031/0.032, rel reduction: -0.00649
# [2023-02-03 12:19:54.205] [info] LM<sym::Optimize> [iter   16] lambda: 1.000e+00, error prev/linear/new: 0.032/0.032/0.032, rel reduction: 0.00209
# [2023-02-03 12:19:54.208] [info] LM<sym::Optimize> [iter   17] lambda: 2.500e-01, error prev/linear/new: 0.032/0.032/0.032, rel reduction: 0.00287
# [2023-02-03 12:19:54.210] [info] LM<sym::Optimize> [iter   18] lambda: 6.250e-02, error prev/linear/new: 0.032/0.031/0.032, rel reduction: -0.02661
# [2023-02-03 12:19:54.212] [info] LM<sym::Optimize> [iter   19] lambda: 2.500e-01, error prev/linear/new: 0.032/0.031/0.032, rel reduction: 0.00026
# [2023-02-03 12:19:54.215] [info] LM<sym::Optimize> [iter   20] lambda: 6.250e-02, error prev/linear/new: 0.032/0.031/0.035, rel reduction: -0.11822
# [2023-02-03 12:19:54.217] [info] LM<sym::Optimize> [iter   21] lambda: 2.500e-01, error prev/linear/new: 0.032/0.031/0.032, rel reduction: -0.00956
# [2023-02-03 12:19:54.220] [info] LM<sym::Optimize> [iter   22] lambda: 1.000e+00, error prev/linear/new: 0.032/0.031/0.032, rel reduction: 0.00262
# [2023-02-03 12:19:54.222] [info] LM<sym::Optimize> [iter   23] lambda: 2.500e-01, error prev/linear/new: 0.032/0.031/0.031, rel reduction: 0.00167
# [2023-02-03 12:19:54.225] [info] LM<sym::Optimize> [iter   24] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.01675
# [2023-02-03 12:19:54.227] [info] LM<sym::Optimize> [iter   25] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.00029
# [2023-02-03 12:19:54.230] [info] LM<sym::Optimize> [iter   26] lambda: 1.000e+00, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00067
# [2023-02-03 12:19:54.232] [info] LM<sym::Optimize> [iter   27] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00132
# [2023-02-03 12:19:54.235] [info] LM<sym::Optimize> [iter   28] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.00472
# [2023-02-03 12:19:54.237] [info] LM<sym::Optimize> [iter   29] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00052
# [2023-02-03 12:19:54.239] [info] LM<sym::Optimize> [iter   30] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.035, rel reduction: -0.10385
# [2023-02-03 12:19:54.242] [info] LM<sym::Optimize> [iter   31] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.00460
# [2023-02-03 12:19:54.244] [info] LM<sym::Optimize> [iter   32] lambda: 1.000e+00, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00096
# [2023-02-03 12:19:54.247] [info] LM<sym::Optimize> [iter   33] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00094
# [2023-02-03 12:19:54.249] [info] LM<sym::Optimize> [iter   34] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.00929
# [2023-02-03 12:19:54.252] [info] LM<sym::Optimize> [iter   35] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00006
# [2023-02-03 12:19:54.254] [info] LM<sym::Optimize> [iter   36] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.033, rel reduction: -0.05777
# [2023-02-03 12:19:54.257] [info] LM<sym::Optimize> [iter   37] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: -0.00431
# [2023-02-03 12:19:54.259] [info] LM<sym::Optimize> [iter   38] lambda: 1.000e+00, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00104
# [2023-02-03 12:19:54.262] [info] LM<sym::Optimize> [iter   39] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00071
# [2023-02-03 12:19:54.264] [info] LM<sym::Optimize> [iter   40] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.00771
# [2023-02-03 12:19:54.267] [info] LM<sym::Optimize> [iter   41] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: -0.00011
# [2023-02-03 12:19:54.269] [info] LM<sym::Optimize> [iter   42] lambda: 1.000e+00, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00030
# [2023-02-03 12:19:54.271] [info] LM<sym::Optimize> [iter   43] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00063
# [2023-02-03 12:19:54.274] [info] LM<sym::Optimize> [iter   44] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.031, rel reduction: -0.00170
# [2023-02-03 12:19:54.276] [info] LM<sym::Optimize> [iter   45] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00031
# [2023-02-03 12:19:54.279] [info] LM<sym::Optimize> [iter   46] lambda: 6.250e-02, error prev/linear/new: 0.031/0.031/0.032, rel reduction: -0.03801
# [2023-02-03 12:19:54.281] [info] LM<sym::Optimize> [iter   47] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: -0.00179
# [0.03139155 0.26340228]
# [2023-02-03 12:19:54.284] [info] LM<sym::Optimize> [iter   48] lambda: 1.000e+00, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00044
# [2023-02-03 12:19:54.286] [info] LM<sym::Optimize> [iter   49] lambda: 2.500e-01, error prev/linear/new: 0.031/0.031/0.031, rel reduction: 0.00051

# %%
import matplotlib.pyplot as plt
lh = np.concatenate(result.optimized_values['landmarks']).reshape([len(lm),2])
xh = np.concatenate(result.optimized_values['poses']).reshape([len(x),2])
print('lh:', lh)
print('xh:', xh)
fig = plt.figure(1)
plt.plot(lm[:, 0], lm[:, 1], 'bo', label='landmarks')
plt.plot(x[:, 0], x[:, 1], 'r.', label='states', markersize=10)
#plot odom
x_odom = np.array([0, 0], dtype=float)
x_odom_hist = [x_odom]
for odom_i in odom:
    x_odom = np.array(x_odom) + np.array(odom_i[:2])
    x_odom_hist.append(x_odom)
x_odom_hist = np.array(x_odom_hist)
plt.plot(x_odom_hist[:, 0], x_odom_hist[:, 1], 'g.', linewidth=3, label='odom')
# plot best estimate history from each time step
plt.plot(xh[:,0], xh[:,1], 'm.', linewidth=3, label='optimal x for each time')
# plot best estimate from the final time step
plt.plot(xh[:,0], xh[:,1], 'y.', linewidth=3, label='optimal x for all time')
# plot best estimate landmarks
plt.plot(lh[:, 0], lh[:, 1], 'ko', label='lh')
#plt.plot(hist['lh'][-1])
# plot measurements
for rng, bearing, xi, li in z:
    xi = int(xi)
    x = xh[xi, :]
    plt.arrow(x[0], x[1], rng*np.cos(bearing) , rng*np.sin(bearing), width=0.1,
                  length_includes_head=True)
# # plot measurements
# for rng, bearing, xi in hist['z']:
#     xi = int(xi)
#     x = x_odom_hist[xi, :]
#     plt.arrow(x[0], x[1], rng*np.cos(bearing) , rng*np.sin(bearing), width=0.1,
#                   length_includes_head=True)
# plt.axis([0, 10, 0, 10])
plt.axis([5, 10, 0, 2])
plt.grid()
plt.legend()
plt.axis('equal');
# Out:
# lh: [[-0.08189255  1.80059846]
#  [ 4.          6.        ]
#  [ 8.81681118  1.08733444]
#  [ 3.9949868   1.84303296]
#  [ 8.71127651  1.46738067]
#  [ 9.11701185 10.08720751]
#  [-4.55819378 15.21444597]]
# xh: [[-4.44640174e-02 -1.48600923e-01]
#  [ 2.00982703e+00 -2.52215488e-01]
#  [ 3.92637349e+00  4.09891861e-01]
#  [ 5.73136441e+00  1.15895708e+00]
#  [ 7.35148100e+00  2.09814330e+00]
#  [ 8.66055281e+00  3.58357955e+00]
#  [ 1.01544808e+01  5.60281232e+00]
#  [ 1.08423985e+01  7.45892127e+00]
#  [ 1.11081964e+01  9.36621407e+00]
#  [ 1.09008935e+01  1.13198330e+01]
#  [ 1.03905640e+01  1.32857921e+01]
#  [ 9.58971947e+00  1.49103654e+01]
#  [ 8.02417474e+00  1.67051870e+01]
#  [ 6.50756790e+00  1.85572655e+01]
#  [ 4.84807796e+00  1.95380690e+01]
#  [ 3.18062062e+00  2.02602307e+01]
#  [ 1.27426763e+00  2.07420637e+01]
#  [-4.96106886e-01  2.05898163e+01]
#  [-2.14353487e+00  1.98414263e+01]
#  [-3.68673265e+00  1.85606880e+01]
#  [-5.44185112e+00  1.72430645e+01]
#  [-6.65936048e+00  1.58231256e+01]
#  [-7.73326540e+00  1.42865178e+01]
#  [-8.79150674e+00  1.20578361e+01]
#  [-9.57679096e+00  9.64847469e+00]
#  [-9.42838044e+00  7.72204898e+00]
#  [-8.82678926e+00  5.71596570e+00]
#  [-7.91996666e+00  3.72264737e+00]
#  [-6.58884403e+00  2.52713892e+00]
#  [-4.77562794e+00  1.26602741e+00]
#  [-2.91048754e+00  5.78904124e-01]
#  [-8.77876507e-01 -1.83569701e-01]
#  [ 1.14491503e+00  2.00878908e-02]
#  [ 2.94571998e+00 -2.94676569e-01]
#  [ 4.90541486e+00 -5.14692420e-01]
#  [ 6.44696896e+00 -1.46665695e+00]
#  [ 7.88871657e+00 -2.67487371e+00]
#  [ 9.28837105e+00 -4.34693130e+00]
#  [ 1.03811238e+01 -6.20051922e+00]
#  [ 1.09958740e+01 -8.62180725e+00]
#  [ 1.12183383e+01 -1.07766356e+01]
#  [ 1.06670040e+01 -1.28145591e+01]
#  [ 9.94453797e+00 -1.47317014e+01]
#  [ 9.07064277e+00 -1.65279275e+01]
#  [ 7.63869650e+00 -1.78141614e+01]
#  [ 6.02192316e+00 -1.87898337e+01]
#  [ 4.04982307e+00 -1.97489207e+01]
#  [ 2.15031714e+00 -2.01471156e+01]
#  [-7.91961913e-02 -1.99652989e+01]
#  [-1.77008359e+00 -1.98977491e+01]
#  [-3.45959550e+00 -1.88464699e+01]
#  [-5.42278903e+00 -1.75307214e+01]
#  [-6.93435026e+00 -1.62895594e+01]
#  [-7.85219255e+00 -1.47718899e+01]
#  [-8.79287993e+00 -1.30477585e+01]
#  [-9.08645857e+00 -1.11364718e+01]
#  [-8.87289820e+00 -9.06979834e+00]
#  [-8.46090629e+00 -7.04094149e+00]
#  [-7.78383384e+00 -5.25716282e+00]
#  [-6.43258645e+00 -3.30569010e+00]
#  [-5.06848134e+00 -1.93360230e+00]]

# %%
# data from sim
odom = sim['hist']['odom']
l = sim['landmarks']
z = sim['hist']['z']
hist = sim['hist']

# initialize x guess from odom
x0 = sim['hist']['x']
# print(x0[:,0].shape)
x1 = x0[:,0]
x2 = x0[:,1]
l1 = l[:,0]
l2 = l[:,1]
x0_new = np.hstack([x1, x2, l1, l2])
n_x = len(hist['x'])
x0_all = np.zeros([n_x+1,2])
x0_all[1: :] = x0

# compute data associations
assoc = [ slam2d.data_association(x0_all[int(xi), :], np.array([rng, bearing]), l) for rng, bearing, xi in z ]
print(assoc)

# build cost
f_J, J = slam2d.build_cost(odom, z, assoc, x0.shape[0], l.shape[0])

# compute cost , this is where we will send it to casadi nonlinear optim
f_J(x0, l)

# Symbols/expressions
nlp = {}                 # NLP declaration
nlp['x']= ca.vertcat(f_J.sx_in()[0][:,0], f_J.sx_in()[0][:,1], f_J.sx_in()[1][:,0], f_J.sx_in()[1][:,1]) # decision vars
nlp['f'] = J           # objective
nlp['g'] = 0             # constraints

# Create solver instance
F = ca.nlpsol('F','ipopt',nlp);

# Solve the problem using a guess
# This uses original landmark/measure association (associates which landmark we think the measurement is measuring)
optim = F(x0=x0_new)

# Re-associate landmark/measurements given new xstar positions
hist = sim['hist']
n_x = len(hist['x'])
n_l = len(sim['landmarks'])
xstar = np.reshape(optim['x'][0:2*n_x], [n_x,2], order='F')
lstar = np.reshape(optim['x'][2*n_x:None], [n_l,2], order='F')
x_allstar = np.zeros([n_x+1,2])
x_allstar[1: :] = xstar

zstar = []
for i in range(n_x):
    x = x_allstar[i,:]
    
    # measure landmarks
    z_list = slam2d.measure_landmarks(x, lstar, noise=noise)

    for z in z_list:
        zstar.append(np.hstack([z, i]))

zstar = np.array(zstar)


new_assoc = [ slam2d.data_association(x_allstar[int(xi), :], np.array([rng, bearing]), lstar) for rng, bearing, xi in zstar ]
print(type(new_assoc))

# # Loop through optimization and reassociation until the new association matches the old association.
# while new_assoc != assoc:
#     # build cost
#     f_J, J = slam2d.build_cost(odom, z, new_assoc, xstar.shape[0], lstar.shape[0])

#     # compute cost , this is where we will send it to casadi nonlinear optim
#     f_J(xstar, l)

#     # Symbols/expressions
#     nlp = {}                 # NLP declaration
#     nlp['x']= ca.vertcat(f_J.sx_in()[0][:,0], f_J.sx_in()[0][:,1], f_J.sx_in()[1][:,0], f_J.sx_in()[1][:,1]) # decision vars
#     nlp['f'] = J           # objective
#     nlp['g'] = 0             # constraints

#     # Create solver instance
#     F = ca.nlpsol('F','ipopt',nlp);

#     # Solve the problem using a guess
#     # This uses original landmark/measure association (associates which landmark we think the measurement is measuring)
#     xstar1 = xstar[:,0]
#     xstar2 = xstar[:,1]
#     lstar1 = l[:,0]
#     lstar2 = l[:,1]
#     xstar_new = np.hstack([xstar1, xstar2, lstar1, lstar2])
#     optim = F(x0=xstar_new)

#     # Re-associate landmark/measurements given new xstar positions
#     hist = sim['hist']
#     n_x = len(hist['x'])
#     n_l = len(sim['landmarks'])
#     xstar = np.reshape(optim['x'][0:2*n_x], [n_x,2], order='F')
#     lstar = np.reshape(optim['x'][2*n_x:None], [n_l,2], order='F')
#     x_allstar = np.zeros([n_x+1,2])
#     x_allstar[1: :] = xstar

#     zstar = []
#     for i in range(n_x):
#         x = x_allstar[i,:]

#         # measure landmarks
#         z_list = slam2d.measure_landmarks(x, lstar, noise=noise)

#         for z in z_list:
#             zstar.append(np.hstack([z, i]))

#     zstar = np.array(zstar)


#     new_assoc = [ slam2d.data_association(x_allstar[int(xi), :], np.array([rng, bearing]), lstar) for rng, bearing, xi in zstar ]

# %%
hist = sim['hist']
n_x = len(hist['x'])
n_l = len(sim['landmarks'])
xstar = np.zeros([n_x+1,2])
xstar[1: :] = np.reshape(optim['x'][0:2*n_x], [n_x,2], order='F')
lstar = np.reshape(optim['x'][2*n_x:None], [n_l,2], order='F')
print(optim['f'])
plt.figure(figsize=(10, 5))
slam2d.plot_me(sim)
for rng, bearing, xi in hist['z']:
    xi = int(xi)
    x = xstar[xi, :]
    # plt.arrow(x[0], x[1], rng*np.cos(bearing) , rng*np.sin(bearing), width=0.1,
    #               length_includes_head=True)
plt.plot(xstar[:, 0], xstar[:, 1], 'm.', linewidth=3, label='xstar')
plt.plot(lstar[:, 0], lstar[:, 1], 'ko', label='lstar')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5921/3083498489.py in <module>
#       1 hist = sim['hist']
#       2 n_x = len(hist['x'])
# ----> 3 n_l = len(sim['landmarks'])
#       4 xstar = np.zeros([n_x+1,2])
#       5 xstar[1: :] = np.reshape(optim['x'][0:2*n_x], [n_x,2], order='F')
#
# KeyError: 'landmarks'

# %%
for lcv in range(1000):
    x = np.random.uniform(-1, 1)
    x_norm = (np.random.randn() + 0) / (4) * 1
    x2 = np.random.randn()
    # plt.plot(lcv,x,'r.')
    # plt.plot(lcv,x2,'k.')
    plt.plot(lcv,x_norm,'m.')

# %%
ca.__version__
# Out:
# '3.5.5'
